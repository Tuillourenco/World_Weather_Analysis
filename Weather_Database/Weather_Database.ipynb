# %%
# https://github.com/emadnhasan/Weather_Database/blob/main/Weather_Database.ipynb

# %%
# Import Dependencies.
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy
import random

# Import API Keys
from config import weather_api_key
from config import g_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 767

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + cities[i]
    

for i, city in enumerate(cities):

    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Retrieve lat and long, max temp, % humidity, % cloudness, wind speed, and weather description
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | phuket
# Processing Record 2 of Set 16 | rikitea
# Processing Record 3 of Set 16 | faya
# Processing Record 4 of Set 16 | saint-francois
# Processing Record 5 of Set 16 | lagoa
# Processing Record 6 of Set 16 | mahebourg
# Processing Record 7 of Set 16 | east london
# Processing Record 8 of Set 16 | kaitangata
# Processing Record 9 of Set 16 | mana
# Processing Record 10 of Set 16 | pangai
# Processing Record 11 of Set 16 | new norfolk
# Processing Record 12 of Set 16 | kavieng
# Processing Record 13 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 16 | tahta
# Processing Record 15 of Set 16 | tilichiki
# Processing Record 16 of Set 16 | cherskiy
# Processing Record 17 of Set 16 | constitucion
# Processing Record 18 of Set 16 | champerico
# Processing Record 19 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 16 | satuk
# Processing Record 21 of Set 16 | ushuaia
# Processing Record 22 of Set 16 | port hueneme
# Processing Record 23 of Set 16 | kajaani
# Processing Record 24 of Set 16 | nikolskoye
# Processing Record 25 of Set 16 | hobart
# Processing Record 26 of Set 16 | avarua
# Processing Record 27 of Set 16 | alta floresta
# Processing Record 28 of Set 16 | bathsheba
# Processing Record 29 of Set 16 | busselton
# Processing Record 30 of Set 16 | lages
# Processing Record 31 of Set 16 | kawalu
# Processing Record 32 of Set 16 | mataura
# Processing Record 33 of Set 16 | ukiah
# Processing Record 34 of Set 16 | esperance
# Processing Record 35 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 16 | upington
# Processing Record 37 of Set 16 | varamin
# Processing Record 38 of Set 16 | albany
# Processing Record 39 of Set 16 | jamestown
# Processing Record 40 of Set 16 | uhlove
# Processing Record 41 of Set 16 | pevek
# Processing Record 42 of Set 16 | vaini
# Processing Record 43 of Set 16 | kudus
# Processing Record 44 of Set 16 | upernavik
# Processing Record 45 of Set 16 | dangtu
# Processing Record 46 of Set 16 | ancud
# Processing Record 47 of Set 16 | padang
# Processing Record 48 of Set 16 | obluche
# City not found. Skipping...
# Processing Record 49 of Set 16 | pacific grove
# Processing Record 50 of Set 16 | castro
# Processing Record 1 of Set 17 | sabha
# Processing Record 2 of Set 17 | lebu
# Processing Record 3 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 17 | saint george
# Processing Record 5 of Set 17 | gilbues
# Processing Record 6 of Set 17 | isiro
# Processing Record 7 of Set 17 | saint-joseph
# Processing Record 8 of Set 17 | semnan
# Processing Record 9 of Set 17 | butaritari
# Processing Record 10 of Set 17 | cidreira
# Processing Record 11 of Set 17 | clyde river
# Processing Record 12 of Set 17 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 17 | saint-philippe
# Processing Record 14 of Set 17 | port elizabeth
# Processing Record 15 of Set 17 | khatanga
# Processing Record 16 of Set 17 | sao joao da barra
# Processing Record 17 of Set 17 | bluff
# Processing Record 18 of Set 17 | baculin
# Processing Record 19 of Set 17 | kodiak
# Processing Record 20 of Set 17 | tiksi
# Processing Record 21 of Set 17 | faanui
# Processing Record 22 of Set 17 | nanortalik
# Processing Record 23 of Set 17 | punta arenas
# Processing Record 24 of Set 17 | port augusta
# Processing Record 25 of Set 17 | codrington
# Processing Record 26 of Set 17 | halifax
# Processing Record 27 of Set 17 | hudiksvall
# Processing Record 28 of Set 17 | airai
# Processing Record 29 of Set 17 | port alfred
# Processing Record 30 of Set 17 | asosa
# Processing Record 31 of Set 17 | cabedelo
# Processing Record 32 of Set 17 | kiama
# Processing Record 33 of Set 17 | sheksna
# Processing Record 34 of Set 17 | dikson
# Processing Record 35 of Set 17 | biltine
# Processing Record 36 of Set 17 | isangel
# Processing Record 37 of Set 17 | talnakh
# Processing Record 38 of Set 17 | keningau
# Processing Record 39 of Set 17 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 17 | pisco
# Processing Record 41 of Set 17 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 17 | eureka
# Processing Record 43 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 17 | hermanus
# Processing Record 45 of Set 17 | ponta do sol
# Processing Record 46 of Set 17 | thompson
# Processing Record 47 of Set 17 | yellowknife
# Processing Record 48 of Set 17 | qaanaaq
# Processing Record 49 of Set 17 | cabildo
# Processing Record 50 of Set 17 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 18 | port blair
# Processing Record 2 of Set 18 | norman wells
# Processing Record 3 of Set 18 | san jose
# Processing Record 4 of Set 18 | puerto ayora
# Processing Record 5 of Set 18 | sitka
# Processing Record 6 of Set 18 | hami
# Processing Record 7 of Set 18 | jinka
# Processing Record 8 of Set 18 | kungurtug
# Processing Record 9 of Set 18 | georgetown
# Processing Record 10 of Set 18 | valparaiso
# Processing Record 11 of Set 18 | chokurdakh
# Processing Record 12 of Set 18 | svetlogorsk
# Processing Record 13 of Set 18 | wattegama
# Processing Record 14 of Set 18 | xiuyan
# Processing Record 15 of Set 18 | vysokogornyy
# Processing Record 16 of Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 18 | demyansk
# Processing Record 18 of Set 18 | naze
# Processing Record 19 of Set 18 | dingle
# Processing Record 20 of Set 18 | gat
# Processing Record 21 of Set 18 | hithadhoo
# Processing Record 22 of Set 18 | boca do acre
# Processing Record 23 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 18 | dicamay
# Processing Record 25 of Set 18 | komsomolskiy
# Processing Record 26 of Set 18 | papara
# Processing Record 27 of Set 18 | lompoc
# Processing Record 28 of Set 18 | ternate
# Processing Record 29 of Set 18 | cordele
# Processing Record 30 of Set 18 | bredasdorp
# Processing Record 31 of Set 18 | farafangana
# Processing Record 32 of Set 18 | tuktoyaktuk
# Processing Record 33 of Set 18 | rocky mountain house
# Processing Record 34 of Set 18 | san fernando
# Processing Record 35 of Set 18 | kimbe
# Processing Record 36 of Set 18 | nizwa
# Processing Record 37 of Set 18 | jiwani
# Processing Record 38 of Set 18 | aranos
# Processing Record 39 of Set 18 | kapaa
# Processing Record 40 of Set 18 | yemelyanovo
# Processing Record 41 of Set 18 | kruisfontein
# Processing Record 42 of Set 18 | cayenne
# Processing Record 43 of Set 18 | hurghada
# Processing Record 44 of Set 18 | dakoro
# Processing Record 45 of Set 18 | genhe
# Processing Record 46 of Set 18 | alofi
# Processing Record 47 of Set 18 | tagusao
# Processing Record 48 of Set 18 | saint-pierre
# Processing Record 49 of Set 18 | vardo
# Processing Record 50 of Set 18 | tuatapere
# Processing Record 1 of Set 19 | acapulco
# Processing Record 2 of Set 19 | hilo
# Processing Record 3 of Set 19 | ribeira grande
# Processing Record 4 of Set 19 | kilindoni
# Processing Record 5 of Set 19 | carnarvon
# Processing Record 6 of Set 19 | chegdomyn
# Processing Record 7 of Set 19 | asau
# Processing Record 8 of Set 19 | nalut
# Processing Record 9 of Set 19 | brae
# Processing Record 10 of Set 19 | taltal
# Processing Record 11 of Set 19 | hovd
# Processing Record 12 of Set 19 | raudeberg
# Processing Record 13 of Set 19 | hobyo
# Processing Record 14 of Set 19 | tateyama
# Processing Record 15 of Set 19 | angra
# City not found. Skipping...
# Processing Record 16 of Set 19 | togur
# Processing Record 17 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 19 | cabinda
# Processing Record 19 of Set 19 | atuona
# Processing Record 20 of Set 19 | tiruchchendur
# Processing Record 21 of Set 19 | lorengau
# Processing Record 22 of Set 19 | lastoursville
# Processing Record 23 of Set 19 | mandalgovi
# Processing Record 24 of Set 19 | musoma
# Processing Record 25 of Set 19 | lalitpur
# Processing Record 26 of Set 19 | behbahan
# Processing Record 27 of Set 19 | bambous virieux
# Processing Record 28 of Set 19 | half moon bay
# Processing Record 29 of Set 19 | puri
# Processing Record 30 of Set 19 | jarjis
# City not found. Skipping...
# Processing Record 31 of Set 19 | kayerkan
# Processing Record 32 of Set 19 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 19 | slave lake
# Processing Record 34 of Set 19 | yar-sale
# Processing Record 35 of Set 19 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 19 | saldanha
# Processing Record 37 of Set 19 | hokitika
# Processing Record 38 of Set 19 | titay
# Processing Record 39 of Set 19 | tigil
# Processing Record 40 of Set 19 | provideniya
# Processing Record 41 of Set 19 | hoi an
# Processing Record 42 of Set 19 | juneau
# Processing Record 43 of Set 19 | klaksvik
# Processing Record 44 of Set 19 | inirida
# Processing Record 45 of Set 19 | anadyr
# Processing Record 46 of Set 19 | morondava
# Processing Record 47 of Set 19 | havoysund
# Processing Record 48 of Set 19 | touros
# Processing Record 49 of Set 19 | udachnyy
# Processing Record 50 of Set 19 | tommot
# Processing Record 1 of Set 20 | arraial do cabo
# Processing Record 2 of Set 20 | mogadishu
# Processing Record 3 of Set 20 | islamkot
# Processing Record 4 of Set 20 | bengkulu
# Processing Record 5 of Set 20 | coxim
# Processing Record 6 of Set 20 | cape town
# Processing Record 7 of Set 20 | sinop
# Processing Record 8 of Set 20 | tasiilaq
# Processing Record 9 of Set 20 | coihaique
# Processing Record 10 of Set 20 | fasa
# Processing Record 11 of Set 20 | chaa-khol
# City not found. Skipping...
# Processing Record 12 of Set 20 | sioux lookout
# Processing Record 13 of Set 20 | mount gambier
# Processing Record 14 of Set 20 | bubaque
# Processing Record 15 of Set 20 | hwange
# Processing Record 16 of Set 20 | victoria
# Processing Record 17 of Set 20 | rothes
# Processing Record 18 of Set 20 | killybegs
# Processing Record 19 of Set 20 | urubicha
# Processing Record 20 of Set 20 | barrow
# Processing Record 21 of Set 20 | katsuura
# Processing Record 22 of Set 20 | guayaramerin
# Processing Record 23 of Set 20 | sartell
# Processing Record 24 of Set 20 | cairns
# Processing Record 25 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 20 | rocha
# Processing Record 27 of Set 20 | souillac
# Processing Record 28 of Set 20 | ereymentau
# Processing Record 29 of Set 20 | bayir
# Processing Record 30 of Set 20 | pokosnoye
# Processing Record 31 of Set 20 | pangnirtung
# Processing Record 32 of Set 20 | husavik
# Processing Record 33 of Set 20 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 20 | cooma
# Processing Record 35 of Set 20 | camacha
# Processing Record 36 of Set 20 | chuy
# Processing Record 37 of Set 20 | beringovskiy
# Processing Record 38 of Set 20 | iqaluit
# Processing Record 39 of Set 20 | aykhal
# Processing Record 40 of Set 20 | amahai
# Processing Record 41 of Set 20 | baripada
# Processing Record 42 of Set 20 | muyezerskiy
# Processing Record 43 of Set 20 | torbay
# Processing Record 44 of Set 20 | kropotkin
# Processing Record 45 of Set 20 | bekeshevskaya
# Processing Record 46 of Set 20 | alice springs
# Processing Record 47 of Set 20 | miri
# Processing Record 48 of Set 20 | leningradskiy
# Processing Record 49 of Set 20 | fomboni
# Processing Record 50 of Set 20 | lensk
# Processing Record 1 of Set 21 | waingapu
# Processing Record 2 of Set 21 | sawakin
# Processing Record 3 of Set 21 | chunskiy
# Processing Record 4 of Set 21 | prattville
# Processing Record 5 of Set 21 | coracao de maria
# Processing Record 6 of Set 21 | muisne
# Processing Record 7 of Set 21 | yenagoa
# Processing Record 8 of Set 21 | tadine
# Processing Record 9 of Set 21 | snezhnogorsk
# Processing Record 10 of Set 21 | paamiut
# Processing Record 11 of Set 21 | ust-tsilma
# Processing Record 12 of Set 21 | hasaki
# Processing Record 13 of Set 21 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 21 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 21 | sao filipe
# Processing Record 16 of Set 21 | ocampo
# Processing Record 17 of Set 21 | minab
# Processing Record 18 of Set 21 | vung tau
# Processing Record 19 of Set 21 | nantong
# Processing Record 20 of Set 21 | ixtapa
# Processing Record 21 of Set 21 | longyearbyen
# Processing Record 22 of Set 21 | olafsvik
# Processing Record 23 of Set 21 | voyvozh
# Processing Record 24 of Set 21 | cognac
# Processing Record 25 of Set 21 | yanam
# Processing Record 26 of Set 21 | dali
# Processing Record 27 of Set 21 | severo-kurilsk
# Processing Record 28 of Set 21 | saint-leu
# Processing Record 29 of Set 21 | fortuna
# Processing Record 30 of Set 21 | estevan
# Processing Record 31 of Set 21 | lodwar
# Processing Record 32 of Set 21 | samarai
# Processing Record 33 of Set 21 | mersing
# Processing Record 34 of Set 21 | iranshahr
# Processing Record 35 of Set 21 | umm kaddadah
# Processing Record 36 of Set 21 | fiaes
# Processing Record 37 of Set 21 | aguas vermelhas
# Processing Record 38 of Set 21 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 21 | aripuana
# Processing Record 40 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 21 | corowa
# Processing Record 42 of Set 21 | carutapera
# Processing Record 43 of Set 21 | pleshanovo
# Processing Record 44 of Set 21 | novoagansk
# Processing Record 45 of Set 21 | nouadhibou
# Processing Record 46 of Set 21 | minot
# Processing Record 47 of Set 21 | lalmohan
# Processing Record 48 of Set 21 | cartagena
# Processing Record 49 of Set 21 | kouango
# Processing Record 50 of Set 21 | laguna
# Processing Record 1 of Set 22 | atar
# Processing Record 2 of Set 22 | rudnyy
# Processing Record 3 of Set 22 | salina
# Processing Record 4 of Set 22 | doctor juan manuel frutos
# Processing Record 5 of Set 22 | celestun
# Processing Record 6 of Set 22 | ashibetsu
# Processing Record 7 of Set 22 | kahului
# Processing Record 8 of Set 22 | la ronge
# Processing Record 9 of Set 22 | flinders
# Processing Record 10 of Set 22 | biskamzha
# Processing Record 11 of Set 22 | walvis bay
# Processing Record 12 of Set 22 | pachino
# Processing Record 13 of Set 22 | batuan
# Processing Record 14 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 22 | denizli
# Processing Record 16 of Set 22 | vao
# Processing Record 17 of Set 22 | chicama
# Processing Record 18 of Set 22 | kasangulu
# Processing Record 19 of Set 22 | pozoblanco
# Processing Record 20 of Set 22 | tunxi
# City not found. Skipping...
# Processing Record 21 of Set 22 | olinda
# Processing Record 22 of Set 22 | tuy hoa
# Processing Record 23 of Set 22 | narsaq
# Processing Record 24 of Set 22 | mokrous
# Processing Record 25 of Set 22 | santa cruz de la palma
# Processing Record 26 of Set 22 | mezhdurechensk
# Processing Record 27 of Set 22 | kavaratti
# Processing Record 28 of Set 22 | oktyabrskiy
# Processing Record 29 of Set 22 | jalu
# Processing Record 30 of Set 22 | saskylakh
# Processing Record 31 of Set 22 | sao paulo de olivenca
# Processing Record 32 of Set 22 | smithers
# Processing Record 33 of Set 22 | kichera
# Processing Record 34 of Set 22 | ostrovnoy
# Processing Record 35 of Set 22 | staszow
# Processing Record 36 of Set 22 | elizabeth city
# Processing Record 37 of Set 22 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 38 of Set 22 | ikare
# Processing Record 39 of Set 22 | nelson bay
# Processing Record 40 of Set 22 | lavrentiya
# Processing Record 41 of Set 22 | kuznechnoye
# Processing Record 42 of Set 22 | la palma
# Processing Record 43 of Set 22 | rio gallegos
# Processing Record 44 of Set 22 | satellite beach
# Processing Record 45 of Set 22 | sur
# Processing Record 46 of Set 22 | xining
# Processing Record 47 of Set 22 | verkhoyansk
# Processing Record 48 of Set 22 | kamenka
# Processing Record 49 of Set 22 | ilulissat
# Processing Record 50 of Set 22 | cootamundra
# Processing Record 1 of Set 23 | paris
# Processing Record 2 of Set 23 | marsaxlokk
# Processing Record 3 of Set 23 | bulri
# Processing Record 4 of Set 23 | cuiaba
# Processing Record 5 of Set 23 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 23 | hofn
# Processing Record 7 of Set 23 | esmeraldas
# Processing Record 8 of Set 23 | arona
# Processing Record 9 of Set 23 | iwaki
# Processing Record 10 of Set 23 | gua musang
# Processing Record 11 of Set 23 | waverly
# Processing Record 12 of Set 23 | oussouye
# Processing Record 13 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 23 | erenhot
# Processing Record 15 of Set 23 | vila do maio
# Processing Record 16 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 23 | tahe
# Processing Record 19 of Set 23 | bilma
# Processing Record 20 of Set 23 | baykit
# Processing Record 21 of Set 23 | pinotepa nacional
# Processing Record 22 of Set 23 | chateau-thierry
# Processing Record 23 of Set 23 | smirnykh
# Processing Record 24 of Set 23 | mackay
# Processing Record 25 of Set 23 | poopo
# Processing Record 26 of Set 23 | san alberto
# Processing Record 27 of Set 23 | merrill
# Processing Record 28 of Set 23 | geraldton
# Processing Record 29 of Set 23 | rawson
# Processing Record 30 of Set 23 | pontes e lacerda
# Processing Record 31 of Set 23 | coroico
# Processing Record 32 of Set 23 | andros town
# Processing Record 33 of Set 23 | cangzhou
# Processing Record 34 of Set 23 | zhigalovo
# Processing Record 35 of Set 23 | azimur
# City not found. Skipping...
# Processing Record 36 of Set 23 | cheney
# Processing Record 37 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 23 | ilhabela
# Processing Record 39 of Set 23 | mar del plata
# Processing Record 40 of Set 23 | vila franca do campo
# Processing Record 41 of Set 23 | buenos aires
# Processing Record 42 of Set 23 | hamilton
# Processing Record 43 of Set 23 | kashi
# Processing Record 44 of Set 23 | verkhovazhye
# Processing Record 45 of Set 23 | takoradi
# Processing Record 46 of Set 23 | fukue
# Processing Record 47 of Set 23 | camocim
# Processing Record 48 of Set 23 | axim
# Processing Record 49 of Set 23 | cabo san lucas
# Processing Record 50 of Set 23 | thinadhoo
# Processing Record 1 of Set 24 | dalbandin
# Processing Record 2 of Set 24 | teya
# Processing Record 3 of Set 24 | tay ninh
# Processing Record 4 of Set 24 | diamantino
# Processing Record 5 of Set 24 | zhangye
# Processing Record 6 of Set 24 | sorland
# Processing Record 7 of Set 24 | les escoumins
# Processing Record 8 of Set 24 | ende
# Processing Record 9 of Set 24 | tuensang
# Processing Record 10 of Set 24 | jiaohe
# Processing Record 11 of Set 24 | razam
# Processing Record 12 of Set 24 | coquimbo
# Processing Record 13 of Set 24 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 24 | carupano
# Processing Record 15 of Set 24 | quedlinburg
# Processing Record 16 of Set 24 | quelimane
# Processing Record 17 of Set 24 | broome
# Processing Record 18 of Set 24 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 24 | asansol
# Processing Record 20 of Set 24 | berlevag
# Processing Record 21 of Set 24 | chaihe
# Processing Record 22 of Set 24 | kleck
# City not found. Skipping...
# Processing Record 23 of Set 24 | zheleznogorsk
# Processing Record 24 of Set 24 | progreso
# Processing Record 25 of Set 24 | mount isa
# Processing Record 26 of Set 24 | pastavy
# Processing Record 27 of Set 24 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 24 | charleston
# Processing Record 29 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 24 | ghanzi
# Processing Record 31 of Set 24 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 24 | senneterre
# Processing Record 33 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 24 | sarbogard
# Processing Record 35 of Set 24 | moindou
# Processing Record 36 of Set 24 | quatre cocos
# Processing Record 37 of Set 24 | nome
# Processing Record 38 of Set 24 | necochea
# Processing Record 39 of Set 24 | porto belo
# Processing Record 40 of Set 24 | tabuk
# Processing Record 41 of Set 24 | lahij
# Processing Record 42 of Set 24 | gilgit
# Processing Record 43 of Set 24 | belmonte
# Processing Record 44 of Set 24 | namatanai
# Processing Record 45 of Set 24 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 24 | suluq
# Processing Record 47 of Set 24 | issoire
# Processing Record 48 of Set 24 | pangoa
# Processing Record 49 of Set 24 | tarakan
# Processing Record 50 of Set 24 | korla
# Processing Record 1 of Set 25 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 25 | altay
# Processing Record 3 of Set 25 | cortez
# Processing Record 4 of Set 25 | bocaranga
# City not found. Skipping...
# Processing Record 5 of Set 25 | egvekinot
# Processing Record 6 of Set 25 | tila
# Processing Record 7 of Set 25 | islahiye
# Processing Record 8 of Set 25 | batemans bay
# Processing Record 9 of Set 25 | altamirano
# Processing Record 10 of Set 25 | malanje
# Processing Record 11 of Set 25 | hornepayne
# Processing Record 12 of Set 25 | semporna
# Processing Record 13 of Set 25 | deputatskiy
# Processing Record 14 of Set 25 | san cristobal
# Processing Record 15 of Set 25 | prince rupert
# Processing Record 16 of Set 25 | huilong
# Processing Record 17 of Set 25 | novobirilyussy
# Processing Record 18 of Set 25 | yantal
# Processing Record 19 of Set 25 | port lincoln
# Processing Record 20 of Set 25 | sivaki
# Processing Record 21 of Set 25 | yulara
# Processing Record 22 of Set 25 | kigonsera
# Processing Record 23 of Set 25 | mangan
# Processing Record 24 of Set 25 | bagdarin
# Processing Record 25 of Set 25 | kalmar
# Processing Record 26 of Set 25 | scottsboro
# Processing Record 27 of Set 25 | pangkalanbuun
# Processing Record 28 of Set 25 | dangriga
# Processing Record 29 of Set 25 | marawi
# Processing Record 30 of Set 25 | vila velha
# Processing Record 31 of Set 25 | maumere
# Processing Record 32 of Set 25 | san patricio
# Processing Record 33 of Set 25 | hervey bay
# Processing Record 34 of Set 25 | brest
# Processing Record 35 of Set 25 | tiarei
# Processing Record 36 of Set 25 | mehamn
# Processing Record 37 of Set 25 | cuiluan
# Processing Record 38 of Set 25 | hammerfest
# Processing Record 39 of Set 25 | san ramon
# Processing Record 40 of Set 25 | arlit
# Processing Record 41 of Set 25 | ewa beach
# Processing Record 42 of Set 25 | aksarka
# Processing Record 43 of Set 25 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 25 | malinovoye ozero
# Processing Record 45 of Set 25 | college
# Processing Record 46 of Set 25 | tsiroanomandidy
# Processing Record 47 of Set 25 | sept-iles
# Processing Record 48 of Set 25 | biak
# Processing Record 49 of Set 25 | severnoye
# Processing Record 50 of Set 25 | turka
# Processing Record 1 of Set 26 | caloundra
# Processing Record 2 of Set 26 | golden
# Processing Record 3 of Set 26 | usinsk
# Processing Record 4 of Set 26 | parambu
# Processing Record 5 of Set 26 | itarema
# Processing Record 6 of Set 26 | flin flon
# Processing Record 7 of Set 26 | goderich
# Processing Record 8 of Set 26 | huarmey
# Processing Record 9 of Set 26 | svetlaya
# Processing Record 10 of Set 26 | saint-augustin
# Processing Record 11 of Set 26 | kalmunai
# Processing Record 12 of Set 26 | bonavista
# Processing Record 13 of Set 26 | lermontovka
# Processing Record 14 of Set 26 | izhma
# Processing Record 15 of Set 26 | elmina
# Processing Record 16 of Set 26 | westport
# Processing Record 17 of Set 26 | palmer
# Processing Record 18 of Set 26 | karratha
# Processing Record 19 of Set 26 | asuncion
# Processing Record 20 of Set 26 | robertsport
# Processing Record 21 of Set 26 | armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 26 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 26 | port keats
# Processing Record 24 of Set 26 | boke
# Processing Record 25 of Set 26 | lisakovsk
# Processing Record 26 of Set 26 | vallenar
# Processing Record 27 of Set 26 | buala
# Processing Record 28 of Set 26 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 26 | havre-saint-pierre
# Processing Record 30 of Set 26 | tiznit
# Processing Record 31 of Set 26 | taksimo
# Processing Record 32 of Set 26 | mastic beach
# Processing Record 33 of Set 26 | port moresby
# Processing Record 34 of Set 26 | boa vista
# Processing Record 35 of Set 26 | guerrero negro
# Processing Record 36 of Set 26 | muros
# Processing Record 37 of Set 26 | aklavik
# Processing Record 38 of Set 26 | biloela
# Processing Record 39 of Set 26 | zeya
# Processing Record 40 of Set 26 | conde
# Processing Record 41 of Set 26 | port hawkesbury
# Processing Record 42 of Set 26 | avallon
# Processing Record 43 of Set 26 | erzin
# Processing Record 44 of Set 26 | tura
# Processing Record 45 of Set 26 | luderitz
# Processing Record 46 of Set 26 | verkhnevilyuysk
# Processing Record 47 of Set 26 | terrace bay
# Processing Record 48 of Set 26 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 26 | adamas
# Processing Record 50 of Set 26 | vostok
# Processing Record 1 of Set 27 | kingaroy
# Processing Record 2 of Set 27 | ahipara
# Processing Record 3 of Set 27 | sitio novo do tocantins
# Processing Record 4 of Set 27 | gamba
# Processing Record 5 of Set 27 | ciudad bolivar
# Processing Record 6 of Set 27 | batangafo
# Processing Record 7 of Set 27 | beira
# Processing Record 8 of Set 27 | bacabal
# Processing Record 9 of Set 27 | banff
# Processing Record 10 of Set 27 | tevaitoa
# Processing Record 11 of Set 27 | vestmannaeyjar
# Processing Record 12 of Set 27 | vilyuysk
# Processing Record 13 of Set 27 | soldotna
# Processing Record 14 of Set 27 | griffith
# Processing Record 15 of Set 27 | port hedland
# Processing Record 16 of Set 27 | los aquijes
# Processing Record 17 of Set 27 | puerto escondido
# Processing Record 18 of Set 27 | comodoro rivadavia
# Processing Record 19 of Set 27 | dabola
# Processing Record 20 of Set 27 | tshikapa
# Processing Record 21 of Set 27 | kloulklubed
# Processing Record 22 of Set 27 | nogales
# Processing Record 23 of Set 27 | montlucon
# Processing Record 24 of Set 27 | bondoukou
# Processing Record 25 of Set 27 | buon me thuot
# City not found. Skipping...
# Processing Record 26 of Set 27 | nishihara
# Processing Record 27 of Set 27 | mayya
# Processing Record 28 of Set 27 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 27 | kushiro
# Processing Record 30 of Set 27 | chapais
# Processing Record 31 of Set 27 | dubrovka
# Processing Record 32 of Set 27 | pandamatenga
# Processing Record 33 of Set 27 | emerald
# Processing Record 34 of Set 27 | east hartford
# Processing Record 35 of Set 27 | palauig
# Processing Record 36 of Set 27 | ayagoz
# Processing Record 37 of Set 27 | grindavik
# Processing Record 38 of Set 27 | seaside
# Processing Record 39 of Set 27 | mainpuri
# Processing Record 40 of Set 27 | koungou
# Processing Record 41 of Set 27 | sakaraha
# Processing Record 42 of Set 27 | kailua
# Processing Record 43 of Set 27 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 27 | kamaishi
# Processing Record 45 of Set 27 | labuhan
# Processing Record 46 of Set 27 | harper
# Processing Record 47 of Set 27 | porto novo
# Processing Record 48 of Set 27 | manakara
# Processing Record 49 of Set 27 | yokadouma
# Processing Record 50 of Set 27 | mirandela
# Processing Record 1 of Set 28 | mogok
# Processing Record 2 of Set 28 | alacranes
# Processing Record 3 of Set 28 | lircay
# Processing Record 4 of Set 28 | omboue
# Processing Record 5 of Set 28 | richards bay
# Processing Record 6 of Set 28 | chikoy
# City not found. Skipping...
# Processing Record 7 of Set 28 | borgosesia
# Processing Record 8 of Set 28 | lipin bor
# Processing Record 9 of Set 28 | satkhira
# Processing Record 10 of Set 28 | nakamura
# Processing Record 11 of Set 28 | tokonou
# Processing Record 12 of Set 28 | cockburn town
# Processing Record 13 of Set 28 | brigantine
# Processing Record 14 of Set 28 | el sauzal
# Processing Record 15 of Set 28 | hvammstangi
# City not found. Skipping...
# Processing Record 16 of Set 28 | boo
# Processing Record 17 of Set 28 | balabac
# Processing Record 18 of Set 28 | warwick
# Processing Record 19 of Set 28 | perelyub
# Processing Record 20 of Set 28 | dunedin
# Processing Record 21 of Set 28 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 28 | dakar
# Processing Record 23 of Set 28 | mahon
# Processing Record 24 of Set 28 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 28 | haapu
# City not found. Skipping...
# Processing Record 26 of Set 28 | sattahip
# Processing Record 27 of Set 28 | itaituba
# Processing Record 28 of Set 28 | lima
# Processing Record 29 of Set 28 | batticaloa
# Processing Record 30 of Set 28 | taman
# Processing Record 31 of Set 28 | margate
# Processing Record 32 of Set 28 | port hardy
# Processing Record 33 of Set 28 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 28 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 28 | kodinsk
# Processing Record 36 of Set 28 | san juan
# Processing Record 37 of Set 28 | moron
# Processing Record 38 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 28 | kopong
# Processing Record 40 of Set 28 | san quintin
# Processing Record 41 of Set 28 | karagaylinskiy
# Processing Record 42 of Set 28 | lieksa
# Processing Record 43 of Set 28 | doha
# Processing Record 44 of Set 28 | guangyuan
# Processing Record 45 of Set 28 | boguchany
# Processing Record 46 of Set 28 | caldwell
# Processing Record 47 of Set 28 | cordoba
# Processing Record 48 of Set 28 | coahuayana
# Processing Record 49 of Set 28 | santa marta
# Processing Record 50 of Set 28 | hauterive
# Processing Record 1 of Set 29 | zhicheng
# Processing Record 2 of Set 29 | los llanos de aridane
# Processing Record 3 of Set 29 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 29 | piedras negras
# Processing Record 5 of Set 29 | nicoya
# Processing Record 6 of Set 29 | cruz
# Processing Record 7 of Set 29 | sterling
# Processing Record 8 of Set 29 | surt
# Processing Record 9 of Set 29 | kysyl-syr
# Processing Record 10 of Set 29 | honiara
# Processing Record 11 of Set 29 | kilgore
# Processing Record 12 of Set 29 | zlobin
# Processing Record 13 of Set 29 | tapes
# Processing Record 14 of Set 29 | lujan
# Processing Record 15 of Set 29 | karaton
# Processing Record 16 of Set 29 | mendoza
# Processing Record 17 of Set 29 | remontnoye
# Processing Record 18 of Set 29 | vuktyl
# Processing Record 19 of Set 29 | tongliao
# Processing Record 20 of Set 29 | dumas
# Processing Record 21 of Set 29 | khromtau
# Processing Record 22 of Set 29 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 29 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 29 | ishigaki
# Processing Record 25 of Set 29 | khandyga
# Processing Record 26 of Set 29 | maniitsoq
# Processing Record 27 of Set 29 | almaznyy
# Processing Record 28 of Set 29 | artigas
# Processing Record 29 of Set 29 | kanye
# Processing Record 30 of Set 29 | paringao
# Processing Record 31 of Set 29 | key west
# Processing Record 32 of Set 29 | korgen
# Processing Record 33 of Set 29 | zavoronezhskoye
# Processing Record 34 of Set 29 | vestbygda
# City not found. Skipping...
# Processing Record 35 of Set 29 | manaus
# Processing Record 36 of Set 29 | stykkisholmur
# Processing Record 37 of Set 29 | sfantu gheorghe
# Processing Record 38 of Set 29 | zhanaozen
# Processing Record 39 of Set 29 | cervo
# Processing Record 40 of Set 29 | paucartambo
# City not found. Skipping...
# Processing Record 41 of Set 29 | koumac
# Processing Record 42 of Set 29 | poum
# Processing Record 43 of Set 29 | bima
# Processing Record 44 of Set 29 | kattivakkam
# Processing Record 45 of Set 29 | luwuk
# Processing Record 46 of Set 29 | matto
# City not found. Skipping...
# Processing Record 47 of Set 29 | chiredzi
# Processing Record 48 of Set 29 | makakilo city
# Processing Record 49 of Set 29 | raahe
# Processing Record 50 of Set 29 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 30 | taoudenni
# Processing Record 2 of Set 30 | tevriz
# Processing Record 3 of Set 30 | viedma
# Processing Record 4 of Set 30 | kondoa
# Processing Record 5 of Set 30 | antalaha
# Processing Record 6 of Set 30 | kafue
# Processing Record 7 of Set 30 | orizona
# Processing Record 8 of Set 30 | calvinia
# Processing Record 9 of Set 30 | hillsborough
# Processing Record 10 of Set 30 | kaeo
# Processing Record 11 of Set 30 | talmenka
# Processing Record 12 of Set 30 | massaguet
# Processing Record 13 of Set 30 | kargasok
# Processing Record 14 of Set 30 | mahibadhoo
# Processing Record 15 of Set 30 | hualmay
# Processing Record 16 of Set 30 | konakovo
# Processing Record 17 of Set 30 | port-gentil
# Processing Record 18 of Set 30 | portland
# Processing Record 19 of Set 30 | pitkyaranta
# Processing Record 20 of Set 30 | rudnogorsk
# Processing Record 21 of Set 30 | monrovia
# Processing Record 22 of Set 30 | bay roberts
# Processing Record 23 of Set 30 | mamakan
# Processing Record 24 of Set 30 | zhenlai
# Processing Record 25 of Set 30 | henties bay
# Processing Record 26 of Set 30 | ambovombe
# Processing Record 27 of Set 30 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 30 | northam
# Processing Record 29 of Set 30 | krosno
# Processing Record 30 of Set 30 | verdun
# Processing Record 31 of Set 30 | nemuro
# Processing Record 32 of Set 30 | pinheiro machado
# Processing Record 33 of Set 30 | ginda
# Processing Record 34 of Set 30 | burnie
# Processing Record 35 of Set 30 | qaqortoq
# Processing Record 36 of Set 30 | vrangel
# Processing Record 37 of Set 30 | xichang
# Processing Record 38 of Set 30 | madang
# Processing Record 39 of Set 30 | la quinta
# Processing Record 40 of Set 30 | grande-riviere
# City not found. Skipping...
# Processing Record 41 of Set 30 | elko
# Processing Record 42 of Set 30 | menongue
# Processing Record 43 of Set 30 | ulenurme
# Processing Record 44 of Set 30 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 30 | dasoguz
# Processing Record 46 of Set 30 | caravelas
# Processing Record 47 of Set 30 | pavlodolskaya
# Processing Record 48 of Set 30 | russell
# Processing Record 49 of Set 30 | barcelos
# Processing Record 50 of Set 30 | colares
# Processing Record 1 of Set 31 | auki
# Processing Record 2 of Set 31 | ondjiva
# Processing Record 3 of Set 31 | urucara
# Processing Record 4 of Set 31 | lenoir city
# Processing Record 5 of Set 31 | kormilovka
# Processing Record 6 of Set 31 | namibe
# Processing Record 7 of Set 31 | jiazi
# Processing Record 8 of Set 31 | greer
# Processing Record 9 of Set 31 | jhelum
# Processing Record 10 of Set 31 | sibolga
# Processing Record 11 of Set 31 | touba
# Processing Record 12 of Set 31 | chvaletice
# Processing Record 13 of Set 31 | kenner
# Processing Record 14 of Set 31 | maryville
# Processing Record 15 of Set 31 | chernenko
# Processing Record 16 of Set 31 | rolim de moura
# City not found. Skipping...
# Processing Record 17 of Set 31 | koslan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the date format.
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Append Column Names, organizing its structure.
city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})

# %%
#Add the data to a new dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Phuket      TH   8.0000   98.2500     85.12       100          20
# 1         Rikitea      PF -23.1203 -134.9692     71.82        72          93
# 2            Faya      SA  18.3851   42.4509     63.12        72         100
# 3  Saint-Francois      FR  46.4154    3.9054     65.68        77           0
# 4           Lagoa      PT  39.0500  -27.9833     73.98        90          15
# 5       Mahebourg      MU -20.4081   57.7000     68.29        73          40
# 6     East London      ZA -33.0153   27.9116     69.96        54          97
# 7      Kaitangata      NZ -46.2817  169.8464     55.02        60          59
# 8            Mana      GF   5.6592  -53.7767     77.47        89          69
# 9          Pangai      TO -19.8000 -174.3500     80.71        74          20
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1       18.70     overcast clouds
# 2        5.84     overcast clouds
# 3        1.14           clear sky
# 4        4.90          light rain
# 5        5.75    scattered clouds
# 6        8.21     overcast clouds
# 7        5.10       broken clouds
# 8        8.48       broken clouds
# 9       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database.csv")
