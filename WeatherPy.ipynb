# %% [markdown]
# ## Create Latitude and Longitude Combinations

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ## Generate Random World Cities

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 642

# %% [markdown]
# ## Get the City Weather Data

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create Counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | malanje
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | erzin
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | bilma
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | puerto escondido
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | metehara
# City not found. Skipping...
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | sanguem
# Processing Record 23 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | fort nelson
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | vrangel
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | yulara
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 1 | pedregulho
# Processing Record 36 of Set 1 | kristiinankaupunki
# Processing Record 37 of Set 1 | yeppoon
# Processing Record 38 of Set 1 | saint anthony
# Processing Record 39 of Set 1 | chumikan
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | saleilua
# City not found. Skipping...
# Processing Record 44 of Set 1 | makubetsu
# Processing Record 45 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | kursumlija
# Processing Record 48 of Set 1 | buseresere
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | komsomolskiy
# Processing Record 3 of Set 2 | tamworth
# Processing Record 4 of Set 2 | riyadh
# Processing Record 5 of Set 2 | artyom
# Processing Record 6 of Set 2 | uaua
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | minador do negrao
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | mazagao
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | olga
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | meadow lake
# Processing Record 19 of Set 2 | lokosovo
# Processing Record 20 of Set 2 | conde
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | alampur
# Processing Record 23 of Set 2 | kahului
# Processing Record 24 of Set 2 | tessalit
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | chaihe
# Processing Record 27 of Set 2 | domna
# Processing Record 28 of Set 2 | calama
# Processing Record 29 of Set 2 | havoysund
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | baie-comeau
# Processing Record 33 of Set 2 | sept-iles
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | tura
# Processing Record 39 of Set 2 | constitucion
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | trelew
# Processing Record 43 of Set 2 | mahina
# Processing Record 44 of Set 2 | saint-georges
# Processing Record 45 of Set 2 | haines junction
# Processing Record 46 of Set 2 | onega
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | san policarpo
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | gazojak
# Processing Record 3 of Set 3 | kudahuvadhoo
# Processing Record 4 of Set 3 | westport
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | longyan
# Processing Record 8 of Set 3 | kijang
# Processing Record 9 of Set 3 | eydhafushi
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 3 | malartic
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | vestmannaeyjar
# Processing Record 15 of Set 3 | dunedin
# Processing Record 16 of Set 3 | tawau
# Processing Record 17 of Set 3 | tomatlan
# Processing Record 18 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 3 | vila velha
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | kapchorwa
# Processing Record 22 of Set 3 | amapala
# Processing Record 23 of Set 3 | gat
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | saraland
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | buala
# Processing Record 28 of Set 3 | gizo
# Processing Record 29 of Set 3 | nanakuli
# Processing Record 30 of Set 3 | kuusankoski
# Processing Record 31 of Set 3 | dublyany
# Processing Record 32 of Set 3 | somerset
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | pangai
# Processing Record 35 of Set 3 | pimentel
# Processing Record 36 of Set 3 | trairi
# Processing Record 37 of Set 3 | palu
# Processing Record 38 of Set 3 | lincoln
# Processing Record 39 of Set 3 | abu samrah
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | rio grande
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | okhotsk
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | ingham
# Processing Record 47 of Set 3 | presidencia roque saenz pena
# Processing Record 48 of Set 3 | agadir
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | waddan
# Processing Record 1 of Set 4 | albion
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | rocha
# Processing Record 4 of Set 4 | dombarovskiy
# Processing Record 5 of Set 4 | rivera
# Processing Record 6 of Set 4 | lao cai
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | dalby
# Processing Record 9 of Set 4 | marystown
# Processing Record 10 of Set 4 | roma
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | mehamn
# Processing Record 13 of Set 4 | yatou
# Processing Record 14 of Set 4 | jacobina
# Processing Record 15 of Set 4 | santa fe
# Processing Record 16 of Set 4 | jalu
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | inirida
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | plettenberg bay
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | traiguen
# Processing Record 26 of Set 4 | janesville
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | buzmeyin
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | mpanda
# Processing Record 34 of Set 4 | porbandar
# Processing Record 35 of Set 4 | grindavik
# Processing Record 36 of Set 4 | khuzdar
# Processing Record 37 of Set 4 | bidar
# Processing Record 38 of Set 4 | aksarka
# Processing Record 39 of Set 4 | narasannapeta
# Processing Record 40 of Set 4 | lulea
# Processing Record 41 of Set 4 | aykhal
# Processing Record 42 of Set 4 | verkhnyaya inta
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | nefteyugansk
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | sur
# Processing Record 48 of Set 4 | yar-sale
# Processing Record 49 of Set 4 | yellowknife
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | andapa
# Processing Record 2 of Set 5 | yuma
# Processing Record 3 of Set 5 | broome
# Processing Record 4 of Set 5 | jiblah
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | ostrovnoy
# Processing Record 7 of Set 5 | henties bay
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | sabang
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | shizunai
# Processing Record 15 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | hithadhoo
# Processing Record 18 of Set 5 | torbay
# Processing Record 19 of Set 5 | khani
# Processing Record 20 of Set 5 | saint-augustin
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | santander
# Processing Record 23 of Set 5 | lardos
# Processing Record 24 of Set 5 | kasama
# Processing Record 25 of Set 5 | catamarca
# Processing Record 26 of Set 5 | karakol
# Processing Record 27 of Set 5 | humboldt
# Processing Record 28 of Set 5 | kalemie
# Processing Record 29 of Set 5 | kutum
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | qianjiang
# Processing Record 33 of Set 5 | puerto carreno
# Processing Record 34 of Set 5 | ketchikan
# Processing Record 35 of Set 5 | cockburn town
# Processing Record 36 of Set 5 | banda aceh
# Processing Record 37 of Set 5 | cabanglasan
# Processing Record 38 of Set 5 | talcahuano
# Processing Record 39 of Set 5 | darasun
# Processing Record 40 of Set 5 | goderich
# Processing Record 41 of Set 5 | nabire
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | rio gallegos
# Processing Record 44 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 5 | navoloki
# Processing Record 46 of Set 5 | ginir
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | puerto leguizamo
# Processing Record 49 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | ploemeur
# Processing Record 2 of Set 6 | marrakesh
# Processing Record 3 of Set 6 | turukhansk
# Processing Record 4 of Set 6 | half moon bay
# Processing Record 5 of Set 6 | nantucket
# Processing Record 6 of Set 6 | guarapari
# Processing Record 7 of Set 6 | hervey bay
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | petatlan
# Processing Record 10 of Set 6 | mabaruma
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | bowen
# Processing Record 13 of Set 6 | sorland
# Processing Record 14 of Set 6 | durusu
# Processing Record 15 of Set 6 | iranshahr
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | tautira
# Processing Record 18 of Set 6 | micheweni
# Processing Record 19 of Set 6 | araouane
# Processing Record 20 of Set 6 | kenai
# Processing Record 21 of Set 6 | narsaq
# Processing Record 22 of Set 6 | bani
# Processing Record 23 of Set 6 | nichinan
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | burica
# City not found. Skipping...
# Processing Record 26 of Set 6 | kalianget
# Processing Record 27 of Set 6 | kodiak
# Processing Record 28 of Set 6 | bokajan
# Processing Record 29 of Set 6 | severo-yeniseyskiy
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | vao
# Processing Record 33 of Set 6 | the valley
# Processing Record 34 of Set 6 | xihua
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | raton
# Processing Record 37 of Set 6 | vila franca do campo
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | abnub
# Processing Record 41 of Set 6 | olive branch
# Processing Record 42 of Set 6 | palmas bellas
# Processing Record 43 of Set 6 | ceyranbatan
# Processing Record 44 of Set 6 | nikolskoye
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | ust-omchug
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | borama
# City not found. Skipping...
# Processing Record 49 of Set 6 | paciran
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | marmande
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | beloha
# Processing Record 4 of Set 7 | nuuk
# Processing Record 5 of Set 7 | new norfolk
# Processing Record 6 of Set 7 | sakakah
# Processing Record 7 of Set 7 | kuminskiy
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | nicoya
# Processing Record 10 of Set 7 | udachnyy
# Processing Record 11 of Set 7 | sampit
# Processing Record 12 of Set 7 | leeton
# Processing Record 13 of Set 7 | lastoursville
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | zwedru
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | champerico
# Processing Record 18 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 19 of Set 7 | hendrina
# Processing Record 20 of Set 7 | lianzhou
# Processing Record 21 of Set 7 | ankang
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 7 | takoradi
# Processing Record 26 of Set 7 | pokaran
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | nome
# Processing Record 29 of Set 7 | kozulka
# Processing Record 30 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 7 | vaxjo
# Processing Record 32 of Set 7 | galeana
# Processing Record 33 of Set 7 | washougal
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 7 | progreso
# Processing Record 37 of Set 7 | wanaka
# Processing Record 38 of Set 7 | sarahan
# Processing Record 39 of Set 7 | fukue
# Processing Record 40 of Set 7 | leiyang
# Processing Record 41 of Set 7 | sioux lookout
# Processing Record 42 of Set 7 | kirkuk
# Processing Record 43 of Set 7 | uvira
# Processing Record 44 of Set 7 | turkistan
# Processing Record 45 of Set 7 | road town
# Processing Record 46 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 7 | huarmey
# Processing Record 48 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | lompoc
# Processing Record 1 of Set 8 | chokurdakh
# Processing Record 2 of Set 8 | minab
# Processing Record 3 of Set 8 | ishinomaki
# Processing Record 4 of Set 8 | kavaratti
# Processing Record 5 of Set 8 | bom jesus do galho
# Processing Record 6 of Set 8 | rawson
# Processing Record 7 of Set 8 | sargatskoye
# Processing Record 8 of Set 8 | hsinchu
# Processing Record 9 of Set 8 | hay river
# Processing Record 10 of Set 8 | porto velho
# Processing Record 11 of Set 8 | ye
# City not found. Skipping...
# Processing Record 12 of Set 8 | dembi dolo
# Processing Record 13 of Set 8 | alberton
# Processing Record 14 of Set 8 | vuktyl
# Processing Record 15 of Set 8 | liverpool
# Processing Record 16 of Set 8 | akyab
# Processing Record 17 of Set 8 | joaquim gomes
# Processing Record 18 of Set 8 | dingle
# Processing Record 19 of Set 8 | conceicao do araguaia
# Processing Record 20 of Set 8 | kazachinskoye
# Processing Record 21 of Set 8 | ixtapa
# Processing Record 22 of Set 8 | sabile
# Processing Record 23 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 8 | san juan nepomuceno
# Processing Record 25 of Set 8 | marzuq
# Processing Record 26 of Set 8 | asbestos
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | santa maria
# Processing Record 29 of Set 8 | east london
# Processing Record 30 of Set 8 | havre-saint-pierre
# Processing Record 31 of Set 8 | rybinsk
# Processing Record 32 of Set 8 | natal
# Processing Record 33 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | zhangye
# Processing Record 35 of Set 8 | hirara
# Processing Record 36 of Set 8 | zonguldak
# Processing Record 37 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 8 | jiaohe
# Processing Record 39 of Set 8 | honiara
# Processing Record 40 of Set 8 | biak
# Processing Record 41 of Set 8 | mahenge
# Processing Record 42 of Set 8 | karratha
# Processing Record 43 of Set 8 | harindanga
# Processing Record 44 of Set 8 | palmer
# Processing Record 45 of Set 8 | aswan
# Processing Record 46 of Set 8 | matehuala
# Processing Record 47 of Set 8 | poya
# Processing Record 48 of Set 8 | hengshui
# Processing Record 49 of Set 8 | lukow
# Processing Record 50 of Set 8 | mayo
# Processing Record 1 of Set 9 | qasigiannguit
# Processing Record 2 of Set 9 | tygda
# Processing Record 3 of Set 9 | marsh harbour
# Processing Record 4 of Set 9 | doaba
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | gafanha da encarnacao
# Processing Record 8 of Set 9 | san clemente
# Processing Record 9 of Set 9 | zeya
# Processing Record 10 of Set 9 | vostok
# Processing Record 11 of Set 9 | batticaloa
# Processing Record 12 of Set 9 | khor
# Processing Record 13 of Set 9 | havelock
# Processing Record 14 of Set 9 | charters towers
# Processing Record 15 of Set 9 | chicama
# Processing Record 16 of Set 9 | olinda
# Processing Record 17 of Set 9 | kirakira
# Processing Record 18 of Set 9 | hobyo
# Processing Record 19 of Set 9 | muncar
# Processing Record 20 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 9 | koumac
# Processing Record 22 of Set 9 | lebu
# Processing Record 23 of Set 9 | makueni
# Processing Record 24 of Set 9 | casa nova
# Processing Record 25 of Set 9 | rovaniemi
# Processing Record 26 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 9 | scottsbluff
# Processing Record 28 of Set 9 | drumheller
# Processing Record 29 of Set 9 | lazaro cardenas
# Processing Record 30 of Set 9 | harer
# Processing Record 31 of Set 9 | khash
# Processing Record 32 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | koungheul
# Processing Record 35 of Set 9 | caluquembe
# Processing Record 36 of Set 9 | gisborne
# Processing Record 37 of Set 9 | la union
# Processing Record 38 of Set 9 | jales
# Processing Record 39 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 9 | bilibino
# Processing Record 41 of Set 9 | eureka
# Processing Record 42 of Set 9 | kawalu
# Processing Record 43 of Set 9 | vilhena
# Processing Record 44 of Set 9 | nongan
# Processing Record 45 of Set 9 | pirapora
# Processing Record 46 of Set 9 | portland
# Processing Record 47 of Set 9 | port lincoln
# Processing Record 48 of Set 9 | bandarbeyla
# Processing Record 49 of Set 9 | isangel
# Processing Record 50 of Set 9 | strunino
# Processing Record 1 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 10 | makakilo city
# Processing Record 3 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | fort-shevchenko
# Processing Record 6 of Set 10 | zhoucheng
# Processing Record 7 of Set 10 | bathsheba
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | shimoda
# Processing Record 10 of Set 10 | ahipara
# Processing Record 11 of Set 10 | estrela
# Processing Record 12 of Set 10 | villanueva de la serena
# Processing Record 13 of Set 10 | ola
# Processing Record 14 of Set 10 | guiren
# Processing Record 15 of Set 10 | cururupu
# Processing Record 16 of Set 10 | balkhash
# Processing Record 17 of Set 10 | churapcha
# Processing Record 18 of Set 10 | pangnirtung
# Processing Record 19 of Set 10 | porteirinha
# Processing Record 20 of Set 10 | kuala terengganu
# Processing Record 21 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 10 | piacabucu
# Processing Record 23 of Set 10 | birao
# Processing Record 24 of Set 10 | pacific grove
# Processing Record 25 of Set 10 | oranjemund
# Processing Record 26 of Set 10 | port blair
# Processing Record 27 of Set 10 | kautokeino
# Processing Record 28 of Set 10 | vila
# Processing Record 29 of Set 10 | gorlev
# Processing Record 30 of Set 10 | ust-kuyga
# Processing Record 31 of Set 10 | pisco
# Processing Record 32 of Set 10 | dekar
# Processing Record 33 of Set 10 | killybegs
# Processing Record 34 of Set 10 | zhigansk
# Processing Record 35 of Set 10 | queretaro
# Processing Record 36 of Set 10 | maxixe
# Processing Record 37 of Set 10 | bambanglipuro
# Processing Record 38 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 10 | acari
# Processing Record 40 of Set 10 | akureyri
# Processing Record 41 of Set 10 | ariquemes
# Processing Record 42 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 10 | umm kaddadah
# Processing Record 45 of Set 10 | caraquet
# Processing Record 46 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 10 | fortuna
# Processing Record 48 of Set 10 | campbell river
# Processing Record 49 of Set 10 | kargopol
# Processing Record 50 of Set 10 | rodrigues alves
# Processing Record 1 of Set 11 | pontiac
# Processing Record 2 of Set 11 | lockhart
# Processing Record 3 of Set 11 | zhoukou
# Processing Record 4 of Set 11 | teknaf
# Processing Record 5 of Set 11 | talnakh
# Processing Record 6 of Set 11 | rundu
# Processing Record 7 of Set 11 | ormara
# Processing Record 8 of Set 11 | dakar
# Processing Record 9 of Set 11 | mtinko
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | husum
# Processing Record 12 of Set 11 | yerbogachen
# Processing Record 13 of Set 11 | muros
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | rockhampton
# Processing Record 16 of Set 11 | save
# Processing Record 17 of Set 11 | plouzane
# Processing Record 18 of Set 11 | gao
# Processing Record 19 of Set 11 | kinshasa
# Processing Record 20 of Set 11 | san quintin
# Processing Record 21 of Set 11 | honningsvag
# Processing Record 22 of Set 11 | gornopravdinsk
# Processing Record 23 of Set 11 | korostyshiv
# Processing Record 24 of Set 11 | miramar
# Processing Record 25 of Set 11 | abha
# Processing Record 26 of Set 11 | hernani
# Processing Record 27 of Set 11 | dzilam gonzalez
# Processing Record 28 of Set 11 | cidreira
# Processing Record 29 of Set 11 | abu dhabi
# Processing Record 30 of Set 11 | kirovskiy
# Processing Record 31 of Set 11 | sao joao da barra
# Processing Record 32 of Set 11 | berezovka
# Processing Record 33 of Set 11 | campos
# Processing Record 34 of Set 11 | general roca
# Processing Record 35 of Set 11 | khartoum
# Processing Record 36 of Set 11 | bowral
# Processing Record 37 of Set 11 | juneau
# Processing Record 38 of Set 11 | semirom
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | saint-francois
# Processing Record 41 of Set 11 | casablanca
# Processing Record 42 of Set 11 | terrace bay
# Processing Record 43 of Set 11 | eenhana
# Processing Record 44 of Set 11 | noumea
# Processing Record 45 of Set 11 | walvis bay
# Processing Record 46 of Set 11 | salinas
# Processing Record 47 of Set 11 | thaton
# Processing Record 48 of Set 11 | yanam
# Processing Record 49 of Set 11 | zarubino
# Processing Record 50 of Set 11 | saldanha
# Processing Record 1 of Set 12 | onverwacht
# Processing Record 2 of Set 12 | timra
# Processing Record 3 of Set 12 | sfantu gheorghe
# Processing Record 4 of Set 12 | winnemucca
# Processing Record 5 of Set 12 | kurilsk
# Processing Record 6 of Set 12 | poplar bluff
# Processing Record 7 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 8 of Set 12 | bairiki
# Processing Record 9 of Set 12 | mogzon
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | preobrazheniye
# Processing Record 12 of Set 12 | kalaleh
# Processing Record 13 of Set 12 | rio cuarto
# Processing Record 14 of Set 12 | jiangyou
# Processing Record 15 of Set 12 | faya
# Processing Record 16 of Set 12 | camacha
# Processing Record 17 of Set 12 | annavasal
# Processing Record 18 of Set 12 | clyde
# Processing Record 19 of Set 12 | chuy
# Processing Record 20 of Set 12 | san-pedro
# Processing Record 21 of Set 12 | svetlyy
# Processing Record 22 of Set 12 | napuro
# Processing Record 23 of Set 12 | neuquen
# Processing Record 24 of Set 12 | inuvik
# Processing Record 25 of Set 12 | ponta do sol
# Processing Record 26 of Set 12 | tucuman
# Processing Record 27 of Set 12 | wasilla
# Processing Record 28 of Set 12 | hushitai
# Processing Record 29 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 30 of Set 12 | bogorodskoye
# Processing Record 31 of Set 12 | varadero
# Processing Record 32 of Set 12 | shihezi
# Processing Record 33 of Set 12 | singaraja
# Processing Record 34 of Set 12 | hasaki
# Processing Record 35 of Set 12 | orange cove
# Processing Record 36 of Set 12 | carbonia
# Processing Record 37 of Set 12 | middelburg
# Processing Record 38 of Set 12 | boca do acre
# Processing Record 39 of Set 12 | mattru
# Processing Record 40 of Set 12 | oktyabrskiy
# Processing Record 41 of Set 12 | babushkin
# Processing Record 42 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 12 | trincomalee
# Processing Record 44 of Set 12 | sao felix do xingu
# Processing Record 45 of Set 12 | port washington
# Processing Record 46 of Set 12 | arkhara
# Processing Record 47 of Set 12 | sao jose da laje
# Processing Record 48 of Set 12 | napier
# Processing Record 49 of Set 12 | kaeo
# Processing Record 50 of Set 12 | kamina
# Processing Record 1 of Set 13 | binzhou
# Processing Record 2 of Set 13 | kurunegala
# Processing Record 3 of Set 13 | mayumba
# Processing Record 4 of Set 13 | pandan
# Processing Record 5 of Set 13 | khasan
# Processing Record 6 of Set 13 | bata
# Processing Record 7 of Set 13 | haringhata
# Processing Record 8 of Set 13 | beringovskiy
# Processing Record 9 of Set 13 | arvika
# Processing Record 10 of Set 13 | saint-pierre
# Processing Record 11 of Set 13 | colares
# Processing Record 12 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 13 | shakhrinau
# City not found. Skipping...
# Processing Record 14 of Set 13 | ignacio de la llave
# Processing Record 15 of Set 13 | stende
# Processing Record 16 of Set 13 | ehingen
# Processing Record 17 of Set 13 | tocopilla
# Processing Record 18 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 13 | faanui
# Processing Record 20 of Set 13 | taoudenni
# Processing Record 21 of Set 13 | esmeraldas
# Processing Record 22 of Set 13 | menongue
# Processing Record 23 of Set 13 | bhatkal
# Processing Record 24 of Set 13 | kabinda
# Processing Record 25 of Set 13 | boone
# Processing Record 26 of Set 13 | carutapera
# Processing Record 27 of Set 13 | darnah
# Processing Record 28 of Set 13 | hovd
# Processing Record 29 of Set 13 | antofagasta
# Processing Record 30 of Set 13 | college
# Processing Record 31 of Set 13 | aasiaat
# Processing Record 32 of Set 13 | kendallville
# Processing Record 33 of Set 13 | boende
# Processing Record 34 of Set 13 | husavik
# Processing Record 35 of Set 13 | leh
# Processing Record 36 of Set 13 | port hardy
# Processing Record 37 of Set 13 | tabou
# Processing Record 38 of Set 13 | olafsvik
# Processing Record 39 of Set 13 | ergani
# Processing Record 40 of Set 13 | mzimba
# Processing Record 41 of Set 13 | hatillo
# Processing Record 42 of Set 13 | port macquarie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# After collecting all our data, we can tally the number of cities in the city_data array of dictionaries using the len() function.
len(city_data)
# Out:
# 590

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     72.07        72          65
# 1    Georgetown   5.4112  100.3354     78.89        93          40
# 2       Malanje  -9.5402   16.3410     67.01        56          67
# 3         Pevek  69.7008  170.3133     35.20        98         100
# 4      Hermanus -34.4187   19.2345     53.80        84           3
# 5        Dikson  73.5069   80.5464     43.38        97         100
# 6         Erzin  36.9559   36.2000     77.65        90          35
# 7  Punta Arenas -53.1500  -70.9167     39.31        87         100
# 8         Bilma  18.6853   12.9164     89.73        40          41
# 9  San Patricio  28.0170  -97.5169     95.54        54          32
#
#    Wind Speed Country                 Date
# 0       16.28      PF  2022-08-03 23:46:42
# 1        3.44      MY  2022-08-03 23:46:43
# 2        4.09      AO  2022-08-03 23:46:43
# 3        9.15      RU  2022-08-03 23:46:43
# 4       11.59      ZA  2022-08-03 23:46:44
# 5        9.17      RU  2022-08-03 23:46:44
# 6        1.05      TR  2022-08-03 23:46:44
# 7       13.80      CL  2022-08-03 23:46:45
# 8       10.74      NE  2022-08-03 23:46:45
# 9       21.32      US  2022-08-03 23:46:46

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plot Latitude vs. Temperature

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %% [markdown]
# ## Plot Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude v. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %% [markdown]
# ## Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Create a Linear Regression Function

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %% [markdown]
# ## Find the Correlation Between Latitude and Percent Humidity.

# %%
# Linear regression on the Northern Hemisphere (% Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere (% Humidity).
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %% [markdown]
# ## Find the Correlation Between Latitude and Percent Cloudiness.

# %%
# Linear regression on the Northern Hemisphere (% Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere (% Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %% [markdown]
# ## Find the Correlation Between Latitude and Wind Speed.

# %%
# Linear regression on the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %% [markdown]
# ## Set Up Google Maps and Places API
